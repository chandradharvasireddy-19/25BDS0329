# %% [markdown]
# <a href="https://colab.research.google.com/github/chandradharvasireddy-19/25BDS0329/blob/main/exp5_04.08.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
weight=[36,38,45,67,76,49,56,89,109,81]
bins=[30,45,60,80,110]
cat=pd.cut(weight,bins)
cat
# Out:
# [(30, 45], (30, 45], (30, 45], (60, 80], (60, 80], (45, 60], (45, 60], (80, 110], (80, 110], (80, 110]]
# Categories (4, interval[int64, right]): [(30, 45] < (45, 60] < (60, 80] < (80, 110]]

# %%
#checking how many values in each bin
pd.value_counts(cat)
# Out:
# /tmp/ipykernel_1900/888665261.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(cat)
# (30, 45]     3
# (80, 110]    3
# (45, 60]     2
# (60, 80]     2
# Name: count, dtype: int64

# %%
bin_names=['Weak','Moderate','Fit','Obesity']
pd.cut(weight, bins, labels=bin_names)
# Out:
# ['Weak', 'Weak', 'Weak', 'Fit', 'Fit', 'Moderate', 'Moderate', 'Obesity', 'Obesity', 'Obesity']
# Categories (4, object): ['Weak' < 'Moderate' < 'Fit' < 'Obesity']

# %%
import numpy as np
pd.cut(np.random.rand(30), 6, precision=2)
# Out:
# [(0.19, 0.35], (0.033, 0.19], (0.52, 0.68], (0.033, 0.19], (0.19, 0.35], ..., (0.35, 0.52], (0.68, 0.84], (0.84, 1.0], (0.84, 1.0], (0.84, 1.0]]
# Length: 30
# Categories (6, interval[float64, right]): [(0.033, 0.19] < (0.19, 0.35] < (0.35, 0.52] <
#                                            (0.52, 0.68] < (0.68, 0.84] < (0.84, 1.0]]

# %%
randomNumbers = np.random.rand(1000)
category3 = pd.qcut(randomNumbers, 3)
category3
# Out:
# [(-0.0009604, 0.311], (-0.0009604, 0.311], (-0.0009604, 0.311], (0.661, 1.0], (0.661, 1.0], ..., (0.661, 1.0], (-0.0009604, 0.311], (0.311, 0.661], (0.311, 0.661], (-0.0009604, 0.311]]
# Length: 1000
# Categories (3, interval[float64, right]): [(-0.0009604, 0.311] < (0.311, 0.661] < (0.661, 1.0]]

# %%
pd.value_counts(category3)
# Out:
# /tmp/ipykernel_1900/647498483.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category3)
# (0.661, 1.0]           334
# (-0.0009604, 0.311]    333
# (0.311, 0.661]         333
# Name: count, dtype: int64

# %%
df=pd.read_csv('/content/Males.csv')
df.head(10)
# Out:
#    rownames  nr  year  school  exper union   ethn maried health      wage  \
# 0         1  13  1980      14      1    no  other     no     no  1.197540
# 1         2  13  1981      14      2   yes  other     no     no  1.853060
# 2         3  13  1982      14      3    no  other     no     no  1.344462
# 3         4  13  1983      14      4    no  other     no     no  1.433213
# 4         5  13  1984      14      5    no  other     no     no  1.568125
# 5         6  13  1985      14      6    no  other     no     no  1.699891
# 6         7  13  1986      14      7    no  other     no     no -0.720263
# 7         8  13  1987      14      8    no  other     no     no  1.669188
# 8         9  17  1980      13      4    no  other     no     no  1.675962
# 9        10  17  1981      13      5    no  other     no     no  1.518398
#
#                       industry                           occupation  \
# 0  Business_and_Repair_Service                      Service_Workers
# ...

# %%
df['new']=df['nr']*df['school']
df
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 0            1     13  1980      14      1    no  other     no     no
# 1            2     13  1981      14      2   yes  other     no     no
# 2            3     13  1982      14      3    no  other     no     no
# 3            4     13  1983      14      4    no  other     no     no
# 4            5     13  1984      14      5    no  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 4355      4356  12548  1983       9      8    no  other    yes     no
# 4356      4357  12548  1984       9      9   yes  other    yes     no
# 4357      4358  12548  1985       9     10    no  other    yes     no
# 4358      4359  12548  1986       9     11   yes  other    yes     no
# 4359      4360  12548  1987       9     12   yes  other    yes     no
#
#           wage                          industry  \
# 0     1.197540       Business_and_Repair_Service
# ...

# %%
n=df['new']
n[np.abs(n) > 3000]
# Out:
# 112       3270
# 113       3270
# 114       3270
# 115       3270
# 116       3270
#          ...
# 4355    112932
# 4356    112932
# 4357    112932
# 4358    112932
# 4359    112932
# Name: new, Length: 4232, dtype: int64

# %%
df[np.abs(n) > 34634]
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 1200      1201   2685  1980      13      2    no  other     no     no
# 1201      1202   2685  1981      13      3    no  other     no     no
# 1202      1203   2685  1982      13      4    no  other     no     no
# 1203      1204   2685  1983      13      5    no  other     no     no
# 1204      1205   2685  1984      13      6    no  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 4355      4356  12548  1983       9      8    no  other    yes     no
# 4356      4357  12548  1984       9      9   yes  other    yes     no
# 4357      4358  12548  1985       9     10    no  other    yes     no
# 4358      4359  12548  1986       9     11   yes  other    yes     no
# 4359      4360  12548  1987       9     12   yes  other    yes     no
#
#           wage                          industry  \
# 1200  1.840042  Professional_and_Related Service
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
data = {
 'Age': [24, 57, 45, 35, 62],
 'Salary': [50000, 64000, 120000, 85000, 1200000]
}
df = pd.DataFrame(data)
df
# Out:
#    Age   Salary
# 0   24    50000
# 1   57    64000
# 2   45   120000
# 3   35    85000
# 4   62  1200000

# %%
min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(
 min_max_scaler.fit_transform(df),
 columns=df.columns
)
df_min_max
# Out:
#         Age    Salary
# 0  0.000000  0.000000
# 1  0.868421  0.012174
# 2  0.552632  0.060870
# 3  0.289474  0.030435
# 4  1.000000  1.000000

# %%
standard_scaler = StandardScaler()
df_standard = pd.DataFrame(
 standard_scaler.fit_transform(df),
 columns=df.columns
)
df_standard
# Out:
#         Age    Salary
# 0 -1.476560 -0.565609
# 1  0.888803 -0.534409
# 2  0.028671 -0.409609
# 3 -0.688106 -0.487609
# 4  1.247192  1.997236

# %%
# 4. Robust Scaling (Immune to Outliers)
robust_scaler = RobustScaler()
df_robust = pd.DataFrame(
    robust_scaler.fit_transform(df),
    columns=df.columns
)
df_robust
# Out:
#         Age     Salary
# 0 -0.954545  -0.625000
# 1  0.545455  -0.375000
# 2  0.000000   0.625000
# 3 -0.454545   0.000000
# 4  0.772727  19.910714
